# %% [markdown]
# ## Cypher Based Recommendations

# %%
import pandas as pd
import numpy as np
from neo4j import GraphDatabase
from scipy import sparse
import datetime as dt

uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "password"))

# %%
# Get all customer ID's and all products ID's to create sparse matrix

with driver.session() as session:
    query = """
    MATCH (c:Customer)
    RETURN c.id as id
    """
    
    results = session.run(query)
    customers = [record['id'] for record in results]
    
    
    query = """
    MATCH (p:Product)
    RETURN p.code as id
    """ 
    
    results = session.run(query)
    products = [record['id'] for record in results]

# %%
# Create mappings for sparse matrix
# Create mappings
all_product_to_idx = {}
all_idx_to_product = {}
for (idx, prod_id) in enumerate(products):
    all_product_to_idx[prod_id] = idx
    all_idx_to_product[idx] = prod_id
    
all_customer_to_idx = {}
all_idx_to_customer = {}
for (idx, cust_id) in enumerate(customers):
    all_customer_to_idx[cust_id] = idx
    all_idx_to_customer[idx] = cust_id

# %%
# Create lil matrix to incrementally build sparse matrix of recs
n_users = len(customers)
n_products = len(products)

rec_matrix = sparse.lil_matrix((n_users, n_products))

# %%
# Creating class to get recommendations for a user

import logging
import sys
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable

class NeoUserRecommender:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        # Don't forget to close the driver connection when you are finished with it
        self.driver.close()

    @staticmethod
    def enable_log(level, output_stream):
        handler = logging.StreamHandler(output_stream)
        handler.setLevel(level)
        logging.getLogger("neo4j").addHandler(handler)
        logging.getLogger("neo4j").setLevel(level)

    def get_recommended_items_for_user(self, customer_id):
        with self.driver.session(database='fabric') as session:
            # Write transactions allow the driver to handle retries and transient errors
            result = session.read_transaction(
                self._get_recommended_items_for_user, customer_id)
            return result[0]

    @staticmethod
    def _get_recommended_items_for_user(tx, customer_id):
        
        query = ("""
        CALL {
        // Return all purchases for a single customer
        USE fabric.neo4j
        MATCH (c:Customer)-[pur:PURCHASED]->(p:Product)
        WHERE  c.id = $customer_id
        RETURN p.code as prod_code
        }
        CALL {
        // For each of those purchases, return the 10 most similar
        // by image embedding
        USE fabric.products
        WITH prod_code
        MATCH (p1:Product)-[:SIMILAR]->(rec:Product)
        WHERE p1.code = prod_code
        RETURN rec.code as rec_code
        }
        CALL {
        // For each of these recommendations, filter out the ones
        // that don't come from a department or index previously
        // purchases from by the customer
        USE fabric.neo4j
        with rec_code
        MATCH (c:Customer)
        WHERE c.id = $customer_id
        MATCH (ind:Index)<-[:HAS_INDEX]-(rec:Product)-[:FROM_DEPARTMENT]->(d:Department)
        WHERE rec.code = rec_code
        AND EXISTS ((c)-[:PURCHASED]->(:Product)-[:FROM_DEPARTMENT]->(d))
        AND EXISTS ((c)-[:PURCHASED]->(:Product)-[:HAS_INDEX]->(ind))
        RETURN rec.code AS recommended_item
        }
        
        RETURN collect(recommended_item) as recommended_items
        """
        )
        result = tx.run(query, customer_id=customer_id)
        try:
            return [row['recommended_items'] for row in result]
        # Capture any errors along with the query and data for traceability
        except ServiceUnavailable as exception:
            logging.error(f"{query} raised an error: \n {exception}")
            raise
            
    
    def get_cypher_recs_for_user(self, customer_id):
        with self.driver.session(database='neo4j') as session:
            # Write transactions allow the driver to handle retries and transient errors
            result = session.read_transaction(
                self._get_cypher_recs_for_user, customer_id)
            return result[0]

    @staticmethod
    def _get_cypher_recs_for_user(tx, customer_id):

        query = """
        MATCH (c:Customer {id: $customer_id})-[:PURCHASED]->(p:Product)<-[:PURCHASED]-(:Customer)-[:PURCHASED]->(rec:Product) 
        WHERE id(p) <> id(rec)
        AND NOT EXISTS ((c)-[:PURCHASED]->(rec))
        WITH c.id as customer_id, rec, COUNT(rec) as score ORDER BY COUNT(rec) DESC LIMIT 12
        RETURN collect(rec.code) as recommended_items
        """

        result = tx.run(query, customer_id=customer_id)
        try:
            return [row['recommended_items'] for row in result]
        # Capture any errors along with the query and data for traceability
        except ServiceUnavailable as exception:
            logging.error(f"{query} raised an error: \n {exception}")
            raise

# %%
neo_recs = NeoUserRecommender(uri, 'neo4j', 'password')

# %%
# %%timeit
recs = neo_recs.get_recommended_items_for_user('000097d91384a0c14893c09ed047a963c4fc6a5c021044eec603b323e8c82d1d')
# Out:
# 104 ms ± 14.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
cypher_rec = neo_recs.get_cypher_recs_for_user('000097d91384a0c14893c09ed047a963c4fc6a5c021044eec603b323e8c82d1d')

# %%
cypher_rec
# Out:
# ['0565200032',
#  '0624120004',
#  '0706016001',
#  '0673396002',
#  '0610776002',
#  '0372860001',
#  '0720125001',
#  '0158340001',
#  '0548110002',
#  '0562245001',
#  '0573716012',
#  '0372860002']

# %%
# For each customer, get recommendations and map them to the sparse matrix
for i, cust in enumerate(customers):
    
    customer_index = customer_to_idx[cust]
    
    recs = neo_recs.get_recommended_items_for_user(cust)
    rec_indices = [product_to_idx[rec] for rec in recs]
    
    rec_matrix[customer_index, rec_indices] = 1
    
    if i%10000 == 0:
        print(f'{i} customers processed')
#         to_save = rec_matrix.tocsr()
#         sparse.save_npz('rec_matrix.npz', to_save)
#         del(to_save)
        
rec_matrix = rec_matrix.tocsr()
#sparse.save_npz('rec_matrix.npz', rec_matrix)
# Out:
# 0 customers processed
# 1000 customers processed
# 2000 customers processed
# 3000 customers processed
# 4000 customers processed
# 5000 customers processed
# 6000 customers processed
# 7000 customers processed
# 8000 customers processed
# 9000 customers processed
# 10000 customers processed
# 11000 customers processed
# 12000 customers processed
# 13000 customers processed
# 14000 customers processed
# 15000 customers processed
# 16000 customers processed
# 17000 customers processed
# 18000 customers processed
# 19000 customers processed
# 20000 customers processed
# 21000 customers processed
# 22000 customers processed
# 23000 customers processed
# 24000 customers processed
# 25000 customers processed
# 26000 customers processed
# 27000 customers processed
# 28000 customers processed
# 29000 customers processed
# 30000 customers processed
# 31000 customers processed
# 32000 customers processed
# 33000 customers processed
# 34000 customers processed
# 35000 customers processed
# 36000 customers processed
# 37000 customers processed
# 38000 customers processed
# 39000 customers processed
# 40000 customers processed
# 41000 customers processed
# 42000 customers processed
# 43000 customers processed
# 44000 customers processed
# 45000 customers processed
# 46000 customers processed
# 47000 customers processed
# 48000 customers processed
# 49000 customers processed
# 50000 customers processed
# 51000 customers processed
# 52000 customers processed
# 53000 customers processed
# 54000 customers processed
# 55000 customers processed
# 56000 customers processed
# 57000 customers processed
# 58000 customers processed
# 59000 customers processed
# 60000 customers processed
# 61000 customers processed
# 62000 customers processed
# 63000 customers processed
# 64000 customers processed
# 65000 customers processed
# 66000 customers processed
# 67000 customers processed
# 68000 customers processed
# 69000 customers processed
# 70000 customers processed
# 71000 customers processed
# 72000 customers processed
# 73000 customers processed
# 74000 customers processed
# 75000 customers processed
# 76000 customers processed
# 77000 customers processed
# 78000 customers processed
# 79000 customers processed
# 80000 customers processed
# 81000 customers processed
# 82000 customers processed
# 83000 customers processed
# 84000 customers processed
# 85000 customers processed
# 86000 customers processed
# 87000 customers processed
# 88000 customers processed
# 89000 customers processed
# 90000 customers processed
# 91000 customers processed
# 92000 customers processed
# 93000 customers processed
# 94000 customers processed
# 95000 customers processed
# 96000 customers processed
# 97000 customers processed
# 98000 customers processed
# 99000 customers processed
# 100000 customers processed
# 101000 customers processed
# 102000 customers processed
# 103000 customers processed
# 104000 customers processed
# 105000 customers processed
# 106000 customers processed
# 107000 customers processed
# 108000 customers processed
# 109000 customers processed
# 110000 customers processed
# 111000 customers processed
# 112000 customers processed
# 113000 customers processed
# 114000 customers processed
# 115000 customers processed
# 116000 customers processed
# 117000 customers processed
# 118000 customers processed
# 119000 customers processed
# 120000 customers processed
# 121000 customers processed
# 122000 customers processed
# 123000 customers processed
# 124000 customers processed
# 125000 customers processed
# 126000 customers processed
# 127000 customers processed
# 128000 customers processed
# 129000 customers processed
# 130000 customers processed
# 131000 customers processed
# 132000 customers processed
# 133000 customers processed
# 134000 customers processed
# 135000 customers processed
# 136000 customers processed
# 137000 customers processed
# 138000 customers processed
# 139000 customers processed
# 140000 customers processed
# 141000 customers processed
# 142000 customers processed
# 143000 customers processed
# 144000 customers processed
# 145000 customers processed
# 146000 customers processed
# 147000 customers processed
# 148000 customers processed
# 149000 customers processed
# 150000 customers processed
# 151000 customers processed
# 152000 customers processed
# 153000 customers processed
# 154000 customers processed
# 155000 customers processed
# 156000 customers processed
# 157000 customers processed
# 158000 customers processed
# 159000 customers processed
# 160000 customers processed
# 161000 customers processed
# 162000 customers processed
# 163000 customers processed
# 164000 customers processed
# 165000 customers processed
# 166000 customers processed
# 167000 customers processed
# 168000 customers processed
# 169000 customers processed
# 170000 customers processed
# 171000 customers processed
# 172000 customers processed
# 173000 customers processed
# 174000 customers processed
# 175000 customers processed
# 176000 customers processed
# 177000 customers processed
# 178000 customers processed
# 179000 customers processed
# 180000 customers processed
# 181000 customers processed
# 182000 customers processed
# 183000 customers processed
# 184000 customers processed
# 185000 customers processed
# 186000 customers processed
# 187000 customers processed
# 188000 customers processed
# 189000 customers processed
# 190000 customers processed
# 191000 customers processed
# 192000 customers processed
# 193000 customers processed
# 194000 customers processed
# 195000 customers processed
# 196000 customers processed
# 197000 customers processed
# 198000 customers processed
# 199000 customers processed
# 200000 customers processed
# 201000 customers processed
# 202000 customers processed
# 203000 customers processed
# 204000 customers processed
# 205000 customers processed
# 206000 customers processed
# 207000 customers processed
# 208000 customers processed
# 209000 customers processed
# 210000 customers processed
# 211000 customers processed
# 212000 customers processed
# 213000 customers processed
# 214000 customers processed
# 215000 customers processed
# 216000 customers processed
# 217000 customers processed
# 218000 customers processed
# 219000 customers processed
# 220000 customers processed
# 221000 customers processed
# 222000 customers processed
# 223000 customers processed
# 224000 customers processed
# 225000 customers processed
# 226000 customers processed
# 227000 customers processed
# 228000 customers processed
# 229000 customers processed
# 230000 customers processed
# 231000 customers processed
# 232000 customers processed
# 233000 customers processed
# 234000 customers processed
# 235000 customers processed
# 236000 customers processed
# 237000 customers processed
# 238000 customers processed
# 239000 customers processed
# 240000 customers processed
# 241000 customers processed
# 242000 customers processed
# 243000 customers processed
# 244000 customers processed
# 245000 customers processed
# 246000 customers processed
# 247000 customers processed
# 248000 customers processed
# 249000 customers processed
# 250000 customers processed
# 251000 customers processed
# 252000 customers processed
# 253000 customers processed
# 254000 customers processed
# 255000 customers processed
# 256000 customers processed
# 257000 customers processed
# 258000 customers processed
# 259000 customers processed
# 260000 customers processed
# 261000 customers processed
# 262000 customers processed
# 263000 customers processed
# 264000 customers processed
# 265000 customers processed
# 266000 customers processed
# 267000 customers processed
# 268000 customers processed
# 269000 customers processed
# 270000 customers processed
# 271000 customers processed
# 272000 customers processed
# 273000 customers processed
# 274000 customers processed
# 275000 customers processed
# 276000 customers processed
# 277000 customers processed
# 278000 customers processed
# 279000 customers processed
# 280000 customers processed
# 281000 customers processed
# 282000 customers processed
# 283000 customers processed
# 284000 customers processed
# 285000 customers processed
# 286000 customers processed
# 287000 customers processed
# 288000 customers processed
# 289000 customers processed
# 290000 customers processed
# 291000 customers processed
# 292000 customers processed
# 293000 customers processed
# 294000 customers processed
# 295000 customers processed
# 296000 customers processed
# 297000 customers processed
# 298000 customers processed
# 299000 customers processed
# 300000 customers processed
# 301000 customers processed
# 302000 customers processed
# 303000 customers processed
# 304000 customers processed
# 305000 customers processed
# 306000 customers processed
# 307000 customers processed
# 308000 customers processed
# 309000 customers processed
# 310000 customers processed
# 311000 customers processed
# 312000 customers processed
# 313000 customers processed
# 314000 customers processed
# 315000 customers processed
# 316000 customers processed
# 317000 customers processed
# 318000 customers processed
# 319000 customers processed
# 320000 customers processed
# 321000 customers processed
# 322000 customers processed
# 323000 customers processed
# 324000 customers processed
# 325000 customers processed
# 326000 customers processed
# 327000 customers processed
# 328000 customers processed
# 329000 customers processed
# 330000 customers processed
# 331000 customers processed
# 332000 customers processed
# 333000 customers processed
# 334000 customers processed
# 335000 customers processed
# 336000 customers processed
# 337000 customers processed
# 338000 customers processed
# 339000 customers processed
# 340000 customers processed
# 341000 customers processed
# 342000 customers processed
# 343000 customers processed
# 344000 customers processed
# 345000 customers processed
# 346000 customers processed
# 347000 customers processed
# 348000 customers processed
# 349000 customers processed
# 350000 customers processed
# 351000 customers processed
# 352000 customers processed
# 353000 customers processed
# 354000 customers processed
# 355000 customers processed
# 356000 customers processed
# 357000 customers processed
# 358000 customers processed
# 359000 customers processed
# 360000 customers processed
# 361000 customers processed
# 362000 customers processed
# 363000 customers processed
# 364000 customers processed
# 365000 customers processed
# 366000 customers processed
# 367000 customers processed
# 368000 customers processed
# 369000 customers processed
# 370000 customers processed
# 371000 customers processed
# 372000 customers processed
# 373000 customers processed
# 374000 customers processed
# 375000 customers processed
# 376000 customers processed
# 377000 customers processed
# 378000 customers processed
# 379000 customers processed
# 380000 customers processed
# 381000 customers processed
# 382000 customers processed
# 383000 customers processed
# 384000 customers processed
# 385000 customers processed
# 386000 customers processed
# 387000 customers processed
# 388000 customers processed
# 389000 customers processed
# 390000 customers processed
# 391000 customers processed
# 392000 customers processed
# 393000 customers processed
# 394000 customers processed
# 395000 customers processed
# 396000 customers processed
# 397000 customers processed
# 398000 customers processed
# 399000 customers processed
# 400000 customers processed
# 401000 customers processed
# 402000 customers processed
# 403000 customers processed
# 404000 customers processed
# 405000 customers processed
# 406000 customers processed
# 407000 customers processed
# 408000 customers processed
# 409000 customers processed
# 410000 customers processed
# 411000 customers processed
# 412000 customers processed
# 413000 customers processed
# 414000 customers processed
# 415000 customers processed
# 416000 customers processed
# 417000 customers processed
# 418000 customers processed
# 419000 customers processed
# 420000 customers processed
# 421000 customers processed
# 422000 customers processed
# 423000 customers processed
# 424000 customers processed
# 425000 customers processed
# 426000 customers processed
# 427000 customers processed
# 428000 customers processed
# 429000 customers processed
# 430000 customers processed
# 431000 customers processed
# 432000 customers processed
# 433000 customers processed
# 434000 customers processed
# 435000 customers processed
# 436000 customers processed
# 437000 customers processed
# 438000 customers processed
# 439000 customers processed
# 440000 customers processed
# 441000 customers processed
# 442000 customers processed
# 443000 customers processed
# 444000 customers processed
# 445000 customers processed
# 446000 customers processed
# 447000 customers processed
# 448000 customers processed
# 449000 customers processed
# 450000 customers processed
# 451000 customers processed
# 452000 customers processed
# 453000 customers processed
# 454000 customers processed
# 455000 customers processed
# 456000 customers processed
# 457000 customers processed
# 458000 customers processed
# 459000 customers processed
# 460000 customers processed
# 461000 customers processed
# 462000 customers processed
# 463000 customers processed
# 464000 customers processed
# 465000 customers processed
# 466000 customers processed
# 467000 customers processed
# 468000 customers processed
# 469000 customers processed
# 470000 customers processed
# 471000 customers processed
# 472000 customers processed
# 473000 customers processed
# 474000 customers processed
# 475000 customers processed
# 476000 customers processed
# 477000 customers processed
# 478000 customers processed
# 479000 customers processed
# 480000 customers processed
# 481000 customers processed
# 482000 customers processed
# 483000 customers processed
# 484000 customers processed
# 485000 customers processed
# 486000 customers processed
# 487000 customers processed
# 488000 customers processed
# 489000 customers processed
# 490000 customers processed
# 491000 customers processed
# 492000 customers processed
# 493000 customers processed
# 494000 customers processed
# 495000 customers processed
# 496000 customers processed
# 497000 customers processed
# 498000 customers processed
# 499000 customers processed
# 500000 customers processed
# 501000 customers processed
# 502000 customers processed
# 503000 customers processed
# 504000 customers processed
# 505000 customers processed
# 506000 customers processed
# 507000 customers processed
# 508000 customers processed
# 509000 customers processed
# 510000 customers processed
# 511000 customers processed
# 512000 customers processed
# 513000 customers processed
# 514000 customers processed
# 515000 customers processed
# 516000 customers processed
# 517000 customers processed
# 518000 customers processed
# 519000 customers processed
# 520000 customers processed
# 521000 customers processed
# 522000 customers processed
# 523000 customers processed
# 524000 customers processed
# 525000 customers processed
# 526000 customers processed
# 527000 customers processed
# 528000 customers processed
# 529000 customers processed
# 530000 customers processed
# 531000 customers processed
# 532000 customers processed
# 533000 customers processed
# 534000 customers processed
# 535000 customers processed
# 536000 customers processed
# 537000 customers processed
# 538000 customers processed
# 539000 customers processed
# 540000 customers processed
# 541000 customers processed
# 542000 customers processed
# 543000 customers processed
# 544000 customers processed
# 545000 customers processed
# 546000 customers processed
# 547000 customers processed
# 548000 customers processed
# 549000 customers processed
# 550000 customers processed
# 551000 customers processed
# 552000 customers processed
# 553000 customers processed
# 554000 customers processed
# 555000 customers processed
# 556000 customers processed
# 557000 customers processed
# 558000 customers processed
# 559000 customers processed
# 560000 customers processed
# 561000 customers processed
# 562000 customers processed
# 563000 customers processed
# 564000 customers processed
# 565000 customers processed
# 566000 customers processed
# 567000 customers processed
# 568000 customers processed
# 569000 customers processed
# 570000 customers processed
# 571000 customers processed
# 572000 customers processed
# 573000 customers processed
# 574000 customers processed
# 575000 customers processed
# 576000 customers processed
# 577000 customers processed
# 578000 customers processed
# 579000 customers processed
# 580000 customers processed
# 581000 customers processed
# 582000 customers processed
# 583000 customers processed
# 584000 customers processed
# 585000 customers processed
# 586000 customers processed
# 587000 customers processed
# 588000 customers processed
# 589000 customers processed
# 590000 customers processed
# 591000 customers processed
# 592000 customers processed
# 593000 customers processed
# 594000 customers processed
# 595000 customers processed
# 596000 customers processed
# 597000 customers processed
# 598000 customers processed
# 599000 customers processed
# 600000 customers processed
# 601000 customers processed
# 602000 customers processed
# 603000 customers processed
# 604000 customers processed
# 605000 customers processed
# 606000 customers processed
# 607000 customers processed
# 608000 customers processed
# 609000 customers processed
# 610000 customers processed
# 611000 customers processed
# 612000 customers processed
# 613000 customers processed
# 614000 customers processed
# 615000 customers processed
# 616000 customers processed
# 617000 customers processed
# 618000 customers processed
# 619000 customers processed
# 620000 customers processed
# 621000 customers processed
# 622000 customers processed
# 623000 customers processed
# 624000 customers processed
# 625000 customers processed
# 626000 customers processed
# 627000 customers processed
# 628000 customers processed
# 629000 customers processed
# 630000 customers processed
# 631000 customers processed
# 632000 customers processed
# 633000 customers processed
# 634000 customers processed
# 635000 customers processed
# 636000 customers processed
# 637000 customers processed
# 638000 customers processed
# 639000 customers processed
# 640000 customers processed
# 641000 customers processed
# 642000 customers processed
# 643000 customers processed
# 644000 customers processed
# 645000 customers processed
# 646000 customers processed
# 647000 customers processed
# 648000 customers processed
# 649000 customers processed
# 650000 customers processed
# 651000 customers processed
# 652000 customers processed
# 653000 customers processed
# 654000 customers processed
# 655000 customers processed
# 656000 customers processed
# 657000 customers processed
# 658000 customers processed
# 659000 customers processed
# 660000 customers processed
# 661000 customers processed
# 662000 customers processed
# 663000 customers processed
# 664000 customers processed
# 665000 customers processed
# 666000 customers processed
# 667000 customers processed
# 668000 customers processed
# 669000 customers processed
# 670000 customers processed
# 671000 customers processed
# 672000 customers processed
# 673000 customers processed
# 674000 customers processed
# 675000 customers processed
# 676000 customers processed
# 677000 customers processed
# 678000 customers processed
# 679000 customers processed
# 680000 customers processed
# 681000 customers processed
# 682000 customers processed
# 683000 customers processed
# 684000 customers processed
# 685000 customers processed
# 686000 customers processed
# 687000 customers processed
# 688000 customers processed
# 689000 customers processed
# 690000 customers processed
# 691000 customers processed
# 692000 customers processed
# 693000 customers processed
# 694000 customers processed
# 695000 customers processed
# 696000 customers processed
# 697000 customers processed
# 698000 customers processed
# 699000 customers processed
# 700000 customers processed
# 701000 customers processed
# 702000 customers processed
# 703000 customers processed
# 704000 customers processed
# 705000 customers processed
# 706000 customers processed
# 707000 customers processed
# 708000 customers processed
# 709000 customers processed
# 710000 customers processed
# 711000 customers processed
# 712000 customers processed
# 713000 customers processed
# 714000 customers processed
# 715000 customers processed
# 716000 customers processed
# 717000 customers processed
# 718000 customers processed
# 719000 customers processed
# 720000 customers processed
# 721000 customers processed
# 722000 customers processed
# 723000 customers processed
# 724000 customers processed
# 725000 customers processed
# 726000 customers processed
# 727000 customers processed
# 728000 customers processed
# 729000 customers processed
# 730000 customers processed
# 731000 customers processed
# 732000 customers processed
# 733000 customers processed
# 734000 customers processed
# 735000 customers processed
# 736000 customers processed
# 737000 customers processed
# 738000 customers processed
# 739000 customers processed
# 740000 customers processed
# 741000 customers processed
# 742000 customers processed
# 743000 customers processed
# 744000 customers processed
# 745000 customers processed
# 746000 customers processed
# 747000 customers processed
# 748000 customers processed
# 749000 customers processed
# 750000 customers processed
# 751000 customers processed
# 752000 customers processed
# 753000 customers processed
# 754000 customers processed
# 755000 customers processed
# 756000 customers processed
# 757000 customers processed
# 758000 customers processed
# 759000 customers processed
# 760000 customers processed
# 761000 customers processed
# 762000 customers processed
# 763000 customers processed
# 764000 customers processed
# 765000 customers processed
# 766000 customers processed
# 767000 customers processed
# 768000 customers processed
# 769000 customers processed
# 770000 customers processed
# 771000 customers processed
# 772000 customers processed
# 773000 customers processed
# 774000 customers processed
# 775000 customers processed
# 776000 customers processed
# 777000 customers processed
# 778000 customers processed
# 779000 customers processed
# 780000 customers processed
# 781000 customers processed
# 782000 customers processed
# 783000 customers processed
# 784000 customers processed
# 785000 customers processed
# 786000 customers processed
# 787000 customers processed
# 788000 customers processed
# 789000 customers processed
# 790000 customers processed
# 791000 customers processed
# 792000 customers processed
# 793000 customers processed
# 794000 customers processed
# 795000 customers processed
# 796000 customers processed
# 797000 customers processed
# 798000 customers processed
# 799000 customers processed
# 800000 customers processed
# 801000 customers processed
# 802000 customers processed
# 803000 customers processed
# 804000 customers processed
# 805000 customers processed
# 806000 customers processed
# 807000 customers processed
# 808000 customers processed
# 809000 customers processed
# 810000 customers processed
# 811000 customers processed
# 812000 customers processed
# 813000 customers processed
# 814000 customers processed
# 815000 customers processed
# 816000 customers processed
# 817000 customers processed
# 818000 customers processed
# 819000 customers processed
# 820000 customers processed
# 821000 customers processed
# 822000 customers processed
# 823000 customers processed
# 824000 customers processed
# 825000 customers processed
# 826000 customers processed
# 827000 customers processed
# 828000 customers processed
# 829000 customers processed
# 830000 customers processed
# 831000 customers processed
# 832000 customers processed
# 833000 customers processed
# 834000 customers processed
# 835000 customers processed
# 836000 customers processed
# 837000 customers processed
# 838000 customers processed
# 839000 customers processed
# 840000 customers processed
# 841000 customers processed
# 842000 customers processed
# 843000 customers processed
# 844000 customers processed
# 845000 customers processed
# 846000 customers processed
# 847000 customers processed
# 848000 customers processed
# 849000 customers processed
# 850000 customers processed
# 851000 customers processed
# 852000 customers processed
# 853000 customers processed
# 854000 customers processed
# 855000 customers processed
# 856000 customers processed
# 857000 customers processed
# 858000 customers processed
# 859000 customers processed
# 860000 customers processed
# 861000 customers processed
# 862000 customers processed
# 863000 customers processed
# 864000 customers processed
# 865000 customers processed
# 866000 customers processed
# 867000 customers processed
# 868000 customers processed
# 869000 customers processed
# 870000 customers processed
# 871000 customers processed
# 872000 customers processed
# 873000 customers processed
# 874000 customers processed
# 875000 customers processed
# 876000 customers processed
# 877000 customers processed
# 878000 customers processed
# 879000 customers processed
# 880000 customers processed
# 881000 customers processed
# 882000 customers processed
# 883000 customers processed
# 884000 customers processed
# 885000 customers processed
# 886000 customers processed
# 887000 customers processed
# 888000 customers processed
# 889000 customers processed
# 890000 customers processed
# 891000 customers processed
# 892000 customers processed
# 893000 customers processed
# 894000 customers processed
# 895000 customers processed
# 896000 customers processed
# 897000 customers processed
# 898000 customers processed
# 899000 customers processed
# 900000 customers processed
# 901000 customers processed
# 902000 customers processed
# 903000 customers processed
# 904000 customers processed
# 905000 customers processed
# 906000 customers processed
# 907000 customers processed
# 908000 customers processed
# 909000 customers processed
# 910000 customers processed
# 911000 customers processed
# 912000 customers processed
# 913000 customers processed
# 914000 customers processed
# 915000 customers processed
# 916000 customers processed
# 917000 customers processed
# 918000 customers processed
# 919000 customers processed
# 920000 customers processed
# 921000 customers processed
# 922000 customers processed
# 923000 customers processed
# 924000 customers processed
# 925000 customers processed
# 926000 customers processed
# 927000 customers processed
# 928000 customers processed
# 929000 customers processed
# 930000 customers processed
# 931000 customers processed
# 932000 customers processed
# 933000 customers processed
# 934000 customers processed
# 935000 customers processed
# 936000 customers processed
# 937000 customers processed
# 938000 customers processed
# 939000 customers processed
# 940000 customers processed
# 941000 customers processed
# 942000 customers processed
# 943000 customers processed
# 944000 customers processed
# 945000 customers processed
# 946000 customers processed
# 947000 customers processed
# 948000 customers processed
# 949000 customers processed
# 950000 customers processed
# 951000 customers processed
# 952000 customers processed
# 953000 customers processed
# 954000 customers processed
# 955000 customers processed
# 956000 customers processed
# 957000 customers processed
# 958000 customers processed
# 959000 customers processed
# 960000 customers processed
# 961000 customers processed
# 962000 customers processed
# 963000 customers processed
# 964000 customers processed
# 965000 customers processed
# 966000 customers processed
# 967000 customers processed
# 968000 customers processed
# 969000 customers processed
# 970000 customers processed
# 971000 customers processed
# 972000 customers processed
# 973000 customers processed
# 974000 customers processed
# 975000 customers processed
# 976000 customers processed
# 977000 customers processed
# 978000 customers processed
# 979000 customers processed
# 980000 customers processed
# 981000 customers processed
# 982000 customers processed
# 983000 customers processed
# 984000 customers processed
# 985000 customers processed
# 986000 customers processed
# 987000 customers processed
# 988000 customers processed
# 989000 customers processed
# 990000 customers processed
# 991000 customers processed
# 992000 customers processed
# 993000 customers processed
# 994000 customers processed
# 995000 customers processed
# 996000 customers processed
# 997000 customers processed
# 998000 customers processed
# 999000 customers processed
# 1000000 customers processed
# 1001000 customers processed
# 1002000 customers processed
# 1003000 customers processed
# 1004000 customers processed
# 1005000 customers processed
# 1006000 customers processed
# 1007000 customers processed
# 1008000 customers processed
# 1009000 customers processed
# 1010000 customers processed
# 1011000 customers processed
# 1012000 customers processed
# 1013000 customers processed
# 1014000 customers processed
# 1015000 customers processed
# 1016000 customers processed
# 1017000 customers processed
# 1018000 customers processed
# 1019000 customers processed
# 1020000 customers processed
# 1021000 customers processed
# 1022000 customers processed
# 1023000 customers processed
# 1024000 customers processed
# 1025000 customers processed
# 1026000 customers processed
# 1027000 customers processed
# 1028000 customers processed
# 1029000 customers processed
# 1030000 customers processed
# 1031000 customers processed
# 1032000 customers processed
# 1033000 customers processed
# 1034000 customers processed
# 1035000 customers processed
# 1036000 customers processed
# 1037000 customers processed
# 1038000 customers processed
# 1039000 customers processed
# 1040000 customers processed
# 1041000 customers processed
# 1042000 customers processed
# 1043000 customers processed
# 1044000 customers processed
# 1045000 customers processed
# 1046000 customers processed
# 1047000 customers processed
# 1048000 customers processed
# 1049000 customers processed
# 1050000 customers processed
# 1051000 customers processed
# 1052000 customers processed
# 1053000 customers processed
# 1054000 customers processed
# 1055000 customers processed
# 1056000 customers processed
# 1057000 customers processed
# 1058000 customers processed
# 1059000 customers processed
# 1060000 customers processed
# 1061000 customers processed
# 1062000 customers processed
# 1063000 customers processed
# 1064000 customers processed
# 1065000 customers processed
# 1066000 customers processed
# 1067000 customers processed
# 1068000 customers processed
# 1069000 customers processed
# 1070000 customers processed
# 1071000 customers processed
# 1072000 customers processed
# 1073000 customers processed
# 1074000 customers processed
# 1075000 customers processed
# 1076000 customers processed
# 1077000 customers processed
# 1078000 customers processed
# 1079000 customers processed
# 1080000 customers processed
# 1081000 customers processed
# 1082000 customers processed
# 1083000 customers processed
# 1084000 customers processed
# 1085000 customers processed
# 1086000 customers processed
# 1087000 customers processed
# 1088000 customers processed
# 1089000 customers processed
# 1090000 customers processed
# 1091000 customers processed
# 1092000 customers processed
# 1093000 customers processed
# 1094000 customers processed
# 1095000 customers processed
# 1096000 customers processed
# 1097000 customers processed
# 1098000 customers processed
# 1099000 customers processed
# 1100000 customers processed
# 1101000 customers processed
# 1102000 customers processed
# 1103000 customers processed
# 1104000 customers processed
# 1105000 customers processed
# 1106000 customers processed
# 1107000 customers processed
# 1108000 customers processed
# 1109000 customers processed
# 1110000 customers processed
# 1111000 customers processed
# 1112000 customers processed
# 1113000 customers processed
# 1114000 customers processed
# 1115000 customers processed
# 1116000 customers processed
# 1117000 customers processed
# 1118000 customers processed
# 1119000 customers processed
# 1120000 customers processed
# 1121000 customers processed
# 1122000 customers processed
# 1123000 customers processed
# 1124000 customers processed
# 1125000 customers processed
# 1126000 customers processed
# 1127000 customers processed
# 1128000 customers processed
# 1129000 customers processed
# 1130000 customers processed
# 1131000 customers processed
# 1132000 customers processed
# 1133000 customers processed
# 1134000 customers processed
# 1135000 customers processed
# 1136000 customers processed
# 1137000 customers processed
# 1138000 customers processed
# 1139000 customers processed
# 1140000 customers processed
# 1141000 customers processed
# 1142000 customers processed
# 1143000 customers processed
# 1144000 customers processed
# 1145000 customers processed
# 1146000 customers processed
# 1147000 customers processed
# 1148000 customers processed
# 1149000 customers processed
# 1150000 customers processed
# 1151000 customers processed
# 1152000 customers processed
# 1153000 customers processed
# 1154000 customers processed
# 1155000 customers processed
# 1156000 customers processed
# 1157000 customers processed
# 1158000 customers processed
# 1159000 customers processed
# 1160000 customers processed
# 1161000 customers processed
# 1162000 customers processed
# 1163000 customers processed
# 1164000 customers processed
# 1165000 customers processed
# 1166000 customers processed
# 1167000 customers processed
# 1168000 customers processed
# 1169000 customers processed
# 1170000 customers processed
# 1171000 customers processed
# 1172000 customers processed
# 1173000 customers processed
# 1174000 customers processed
# 1175000 customers processed
# 1176000 customers processed
# 1177000 customers processed
# 1178000 customers processed
# 1179000 customers processed
# 1180000 customers processed
# 1181000 customers processed
# 1182000 customers processed
# 1183000 customers processed
# 1184000 customers processed
# 1185000 customers processed
# 1186000 customers processed
# 1187000 customers processed
# 1188000 customers processed
# 1189000 customers processed
# 1190000 customers processed
# 1191000 customers processed
# 1192000 customers processed
# 1193000 customers processed
# 1194000 customers processed
# 1195000 customers processed
# 1196000 customers processed
# 1197000 customers processed
# 1198000 customers processed
# 1199000 customers processed
# 1200000 customers processed
# 1201000 customers processed
# 1202000 customers processed
# 1203000 customers processed
# 1204000 customers processed
# 1205000 customers processed
# 1206000 customers processed
# 1207000 customers processed
# 1208000 customers processed
# 1209000 customers processed
# 1210000 customers processed
# 1211000 customers processed
# 1212000 customers processed
# 1213000 customers processed
# 1214000 customers processed
# 1215000 customers processed
# 1216000 customers processed
# 1217000 customers processed
# 1218000 customers processed
# 1219000 customers processed
# 1220000 customers processed
# 1221000 customers processed
# 1222000 customers processed
# 1223000 customers processed
# 1224000 customers processed
# 1225000 customers processed
# 1226000 customers processed
# 1227000 customers processed
# 1228000 customers processed
# 1229000 customers processed
# 1230000 customers processed
# 1231000 customers processed
# 1232000 customers processed
# 1233000 customers processed
# 1234000 customers processed
# 1235000 customers processed
# 1236000 customers processed
# 1237000 customers processed
# 1238000 customers processed
# 1239000 customers processed
# 1240000 customers processed
# 1241000 customers processed
# 1242000 customers processed
# 1243000 customers processed
# 1244000 customers processed
# 1245000 customers processed
# 1246000 customers processed
# 1247000 customers processed
# 1248000 customers processed
# 1249000 customers processed
# 1250000 customers processed
# 1251000 customers processed
# 1252000 customers processed
# 1253000 customers processed
# 1254000 customers processed
# 1255000 customers processed
# 1256000 customers processed
# 1257000 customers processed
# 1258000 customers processed
# 1259000 customers processed
# 1260000 customers processed
# 1261000 customers processed
# 1262000 customers processed
# 1263000 customers processed
# 1264000 customers processed
# 1265000 customers processed
# 1266000 customers processed
# 1267000 customers processed
# 1268000 customers processed
# 1269000 customers processed
# 1270000 customers processed
# 1271000 customers processed
# 1272000 customers processed
# 1273000 customers processed
# 1274000 customers processed
# 1275000 customers processed
# 1276000 customers processed
# 1277000 customers processed
# 1278000 customers processed
# 1279000 customers processed
# 1280000 customers processed
# 1281000 customers processed
# 1282000 customers processed
# 1283000 customers processed
# 1284000 customers processed
# 1285000 customers processed
# 1286000 customers processed
# 1287000 customers processed
# 1288000 customers processed
# 1289000 customers processed
# 1290000 customers processed
# 1291000 customers processed
# 1292000 customers processed
# 1293000 customers processed
# 1294000 customers processed
# 1295000 customers processed
# 1296000 customers processed
# 1297000 customers processed
# 1298000 customers processed
# 1299000 customers processed
# 1300000 customers processed
# 1301000 customers processed
# 1302000 customers processed
# 1303000 customers processed
# 1304000 customers processed
# 1305000 customers processed
# 1306000 customers processed
# 1307000 customers processed
# 1308000 customers processed
# 1309000 customers processed
# 1310000 customers processed
# 1311000 customers processed
# 1312000 customers processed
# 1313000 customers processed
# 1314000 customers processed
# 1315000 customers processed
# 1316000 customers processed
# 1317000 customers processed
# 1318000 customers processed
# 1319000 customers processed
# 1320000 customers processed
# 1321000 customers processed
# 1322000 customers processed
# 1323000 customers processed
# 1324000 customers processed
# 1325000 customers processed
# 1326000 customers processed
# 1327000 customers processed
# 1328000 customers processed
# 1329000 customers processed
# 1330000 customers processed
# 1331000 customers processed
# 1332000 customers processed
# 1333000 customers processed
# 1334000 customers processed
# 1335000 customers processed
# 1336000 customers processed
# 1337000 customers processed
# 1338000 customers processed
# 1339000 customers processed
# 1340000 customers processed
# 1341000 customers processed
# 1342000 customers processed
# 1343000 customers processed
# 1344000 customers processed
# 1345000 customers processed
# 1346000 customers processed
# 1347000 customers processed
# 1348000 customers processed
# 1349000 customers processed
# 1350000 customers processed
# 1351000 customers processed
# 1352000 customers processed
# 1353000 customers processed
# 1354000 customers processed
# 1355000 customers processed
# 1356000 customers processed
# 1357000 customers processed
# 1358000 customers processed
# 1359000 customers processed
# 1360000 customers processed
# 1361000 customers processed
# 1362000 customers processed
# 1363000 customers processed
# 1364000 customers processed
# 1365000 customers processed
# 1366000 customers processed
# 1367000 customers processed
# 1368000 customers processed
# 1369000 customers processed
# 1370000 customers processed
# 1371000 customers processed

# %%
rec_matrix = sparse.load_npz('rec_matrix.npz')

# %% [markdown]
# Now we have recommendations for each user based on their purchased items we will use our ALS model to rank these items to get our best 12 items. If a user or item has been filtered out of our data due to not meeting the minimum criteria for purchases, we will revert to a cypher query to find items bought by those who also purchased a product.
#
# We'll use our ALS model from previous blog post, check the post for how we trained it

# %%
import pandas as pd
purchases = pd.read_csv('/Users/grantbeasley/Library/Application Support/Neo4j Desktop/Application/relate-data/dbmss/dbms-8e47f9b7-a408-4d53-915d-8e56e440f5d0/import/transactions_train.csv')

# %%
purchases['t_dat'] = pd.to_datetime(purchases['t_dat'])

# %%
def threshold_likes(df, user_min, article_min):
    n_users = df['customer_id'].unique().shape[0]
    n_items = df['article_id'].unique().shape[0]
    sparsity = float(df.shape[0]) / float(n_users*n_items) * 100
    print('Starting likes info')
    print('Number of users: {}'.format(n_users))
    print('Number of models: {}'.format(n_items))
    print('Sparsity: {:4.3f}%'.format(sparsity))
    
    done = False
    while not done:
        starting_shape = df.shape[0]
        article_counts = df.groupby('customer_id')['article_id'].count()
        df = df[~df['customer_id'].isin(article_counts[article_counts < article_min].index.tolist())]
        user_counts = df.groupby('article_id')['customer_id'].count()
        df = df[~df['article_id'].isin(user_counts[user_counts < user_min].index.tolist())]
        ending_shape = df.shape[0]
        if starting_shape == ending_shape:
            done = True
    
    assert(df.groupby('customer_id')['article_id'].count().min() >= article_min)
    assert(df.groupby('article_id')['customer_id'].count().min() >= user_min)
    
    n_users = df['customer_id'].unique().shape[0]
    n_items = df['article_id'].unique().shape[0]
    sparsity = float(df.shape[0]) / float(n_users*n_items) * 100
    print('Ending likes info')
    print('Number of users: {}'.format(n_users))
    print('Number of models: {}'.format(n_items))
    print('Sparsity: {:4.3f}%'.format(sparsity))
    return df

# %%
purchases_dense = threshold_likes(purchases, 5, 5)
# Out:
# Starting likes info
# Number of users: 1362281
# Number of models: 104547
# Sparsity: 0.022%
# Ending likes info
# Number of users: 925154
# Number of models: 91511
# Sparsity: 0.036%

# %%
# Create mappings
als_product_to_idx = {}
als_idx_to_product = {}
for (idx, aid) in enumerate(purchases_dense['article_id'].unique().tolist()):
    als_product_to_idx[aid] = idx
    als_idx_to_product[idx] = aid
    
als_customer_to_idx = {}
als_idx_to_customer = {}
for (idx, uid) in enumerate(purchases_dense['customer_id'].unique().tolist()):
    als_customer_to_idx[uid] = idx
    als_idx_to_customer[idx] = uid

# %%
def map_ids(row, mapper):
    return mapper[row]

# %%
from scipy import sparse
import numpy as np

I = purchases_dense['customer_id'].apply(map_ids, args=[user_to_idx]).values
J = purchases_dense['article_id'].apply(map_ids, args=[article_to_idx]).values
V = np.ones(I.shape[0])
purchases_sparse = sparse.coo_matrix((V, (I, J)), dtype=np.float64)
purchases_sparse = purchases_sparse.tocsr()

# %%
def assign_confidence_recent(date):
    if date >= dt.date(2020,3,20):
        return 5
    elif (date >= dt.date(2020,3,20)) & (date < dt.date(2020,3,20)): 
        return 3
    else:
        return 1
    
purchases_dense['confidence_recent'] = purchases_dense['t_dat'].apply(assign_confidence_recent)
# Out:
# <ipython-input-16-5394bd22aa06>:2: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   if date >= dt.date(2020,3,20):
# <ipython-input-16-5394bd22aa06>:4: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   elif (date >= dt.date(2020,3,20)) & (date < dt.date(2020,3,20)):

# %%
I = purchases_dense['customer_id'].apply(map_ids, args=[user_to_idx]).values
J = purchases_dense['article_id'].apply(map_ids, args=[article_to_idx]).values
confidence = purchases_dense['confidence_recent'].values 
purchases_with_confidence = sparse.coo_matrix((confidence, (I, J)), dtype=np.float64)
purchases_with_confidence = purchases_with_confidence.tocsr()

# %%
import implicit
als = implicit.als.AlternatingLeastSquares()
als.fit(purchases_with_confidence.T)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# Process:
#     1. Get overall user ID
#     2. Convert user ID to ALS matrix index
#     3. For all recs for a given user, get the ALS index (rec -> product_id -> als_product_index)

# %%
# Create a matrix to hold the recommendations
final_recommendations = sparse.lil_matrix((n_users, n_products))
    
for i, cust in enumerate(customers):

    # Convert the customer_id to the index of all user/items
    all_user_id = all_customer_to_idx[cust]
    
    # Get all the purchases identidied by image similarity and previously written to the user/item matrix
    neo_user_recs = rec_matrix[all_user_id].indices
    
    # Convert all these product_ids to their respective indicies in the user/item matrix
    neo_recs_product_id = [all_idx_to_product[rec] for rec in neo_user_recs]

    # the dataset used to train the ALS model was filtered by num of purchases and sales
    # so first check that the customer was part of the training set
    if cust in als_customer_to_idx and len(neo_recs_product_id) > 0:
        
        # Identify the customers index in the als user/item matrix
        als_user_id = als_customer_to_idx[cust]
        
        # Identify the product index in the als user/item matrix
        als_prod_ids = [als_product_to_idx[int(rec)] for rec in neo_recs_product_id if int(rec) in als_product_to_idx.keys()]
        
        # Providing at least one of the items was part of the als training data - rank the items and take the top 12
        if len(als_prod_ids) > 0:
            ranked_recs = als.rank_items(als_user_id, purchases_with_confidence, selected_items=als_prod_ids)
            ranked_recs = [x[0] for x in ranked_recs[:12]]
            ranked_recs_prod_ids = [als_idx_to_product[x] for x in ranked_recs]
            ranked_recs_all_prod_ids = [all_product_to_idx[f'0{x}'] for x in ranked_recs_prod_ids]

            final_recommendations[all_user_id, ranked_recs_all_prod_ids] = 1

 
    # If we didn't find at least 12 recs, find the extra recs to add
    if final_recommendations.getrow(all_user_id).count_nonzero() < 12:
        
        
        num_to_insert = 12 - final_recommendations.getrow(all_user_id).count_nonzero()
        
        if len(rec_matrix[all_user_id].indices) == 0:
            continue
        
        extra_recs = np.random.choice(rec_matrix[all_user_id].indices, size=num_to_insert)

        final_recommendations[all_user_id, extra_recs] = 1
      
    if i % 10000 == 0:
        print(f'{i} customers processed')
        print(f'{n_users - i} customers remaining')
# Out:
# 0 customers processed
# 1371980 customers remaining
# 10000 customers processed
# 1361980 customers remaining
# 20000 customers processed
# 1351980 customers remaining
# 30000 customers processed
# 1341980 customers remaining
# 40000 customers processed
# 1331980 customers remaining
# 50000 customers processed
# 1321980 customers remaining
# 60000 customers processed
# 1311980 customers remaining
# 70000 customers processed
# 1301980 customers remaining
# 80000 customers processed
# 1291980 customers remaining
# 90000 customers processed
# 1281980 customers remaining
# 100000 customers processed
# 1271980 customers remaining
# 110000 customers processed
# 1261980 customers remaining
# 120000 customers processed
# 1251980 customers remaining
# 130000 customers processed
# 1241980 customers remaining
# 140000 customers processed
# 1231980 customers remaining
# 150000 customers processed
# 1221980 customers remaining
# 180000 customers processed
# 1191980 customers remaining
# 190000 customers processed
# 1181980 customers remaining
# 200000 customers processed
# 1171980 customers remaining
# 210000 customers processed
# 1161980 customers remaining
# 220000 customers processed
# 1151980 customers remaining
# 230000 customers processed
# 1141980 customers remaining
# 240000 customers processed
# 1131980 customers remaining
# 250000 customers processed
# 1121980 customers remaining
# 260000 customers processed
# 1111980 customers remaining
# 270000 customers processed
# 1101980 customers remaining
# 280000 customers processed
# 1091980 customers remaining
# 290000 customers processed
# 1081980 customers remaining
# 300000 customers processed
# 1071980 customers remaining
# 310000 customers processed
# 1061980 customers remaining
# 320000 customers processed
# 1051980 customers remaining
# 330000 customers processed
# 1041980 customers remaining
# 340000 customers processed
# 1031980 customers remaining
# 350000 customers processed
# 1021980 customers remaining
# 360000 customers processed
# 1011980 customers remaining
# 370000 customers processed
# 1001980 customers remaining
# 380000 customers processed
# 991980 customers remaining
# 390000 customers processed
# 981980 customers remaining
# 400000 customers processed
# 971980 customers remaining
# 410000 customers processed
# 961980 customers remaining
# 420000 customers processed
# 951980 customers remaining
# 430000 customers processed
# 941980 customers remaining
# 440000 customers processed
# 931980 customers remaining
# 450000 customers processed
# 921980 customers remaining
# 460000 customers processed
# 911980 customers remaining
# 480000 customers processed
# 891980 customers remaining
# 490000 customers processed
# 881980 customers remaining
# 500000 customers processed
# 871980 customers remaining
# 510000 customers processed
# 861980 customers remaining
# 520000 customers processed
# 851980 customers remaining
# 530000 customers processed
# 841980 customers remaining
# 540000 customers processed
# 831980 customers remaining
# 550000 customers processed
# 821980 customers remaining
# 560000 customers processed
# 811980 customers remaining
# 570000 customers processed
# 801980 customers remaining
# 580000 customers processed
# 791980 customers remaining
# 590000 customers processed
# 781980 customers remaining
# 600000 customers processed
# 771980 customers remaining
# 620000 customers processed
# 751980 customers remaining
# 630000 customers processed
# 741980 customers remaining
# 640000 customers processed
# 731980 customers remaining
# 650000 customers processed
# 721980 customers remaining
# 660000 customers processed
# 711980 customers remaining
# 670000 customers processed
# 701980 customers remaining
# 680000 customers processed
# 691980 customers remaining
# 690000 customers processed
# 681980 customers remaining
# 710000 customers processed
# 661980 customers remaining
# 720000 customers processed
# 651980 customers remaining
# 730000 customers processed
# 641980 customers remaining
# 740000 customers processed
# 631980 customers remaining
# 750000 customers processed
# 621980 customers remaining
# 760000 customers processed
# 611980 customers remaining
# 770000 customers processed
# 601980 customers remaining
# 780000 customers processed
# 591980 customers remaining
# 790000 customers processed
# 581980 customers remaining
# 800000 customers processed
# 571980 customers remaining
# 810000 customers processed
# 561980 customers remaining
# 820000 customers processed
# 551980 customers remaining
# 830000 customers processed
# 541980 customers remaining
# 840000 customers processed
# 531980 customers remaining
# 850000 customers processed
# 521980 customers remaining
# 860000 customers processed
# 511980 customers remaining
# 870000 customers processed
# 501980 customers remaining
# 880000 customers processed
# 491980 customers remaining
# 890000 customers processed
# 481980 customers remaining
# 900000 customers processed
# 471980 customers remaining
# 910000 customers processed
# 461980 customers remaining
# 920000 customers processed
# 451980 customers remaining
# 930000 customers processed
# 441980 customers remaining
# 940000 customers processed
# 431980 customers remaining
# 950000 customers processed
# 421980 customers remaining
# 960000 customers processed
# 411980 customers remaining
# 970000 customers processed
# 401980 customers remaining
# 980000 customers processed
# 391980 customers remaining
# 990000 customers processed
# 381980 customers remaining
# 1000000 customers processed
# 371980 customers remaining
# 1010000 customers processed
# 361980 customers remaining
# 1020000 customers processed
# 351980 customers remaining
# 1030000 customers processed
# 341980 customers remaining
# 1040000 customers processed
# 331980 customers remaining
# 1050000 customers processed
# 321980 customers remaining
# 1060000 customers processed
# 311980 customers remaining
# 1070000 customers processed
# 301980 customers remaining
# 1080000 customers processed
# 291980 customers remaining
# 1090000 customers processed
# 281980 customers remaining
# 1100000 customers processed
# 271980 customers remaining
# 1110000 customers processed
# 261980 customers remaining
# 1120000 customers processed
# 251980 customers remaining
# 1130000 customers processed
# 241980 customers remaining
# 1140000 customers processed
# 231980 customers remaining
# 1150000 customers processed
# 221980 customers remaining
# 1160000 customers processed
# 211980 customers remaining
# 1180000 customers processed
# 191980 customers remaining
# 1190000 customers processed
# 181980 customers remaining
# 1200000 customers processed
# 171980 customers remaining
# 1210000 customers processed
# 161980 customers remaining
# 1220000 customers processed
# 151980 customers remaining
# 1230000 customers processed
# 141980 customers remaining
# 1240000 customers processed
# 131980 customers remaining
# 1250000 customers processed
# 121980 customers remaining
# 1260000 customers processed
# 111980 customers remaining
# 1270000 customers processed
# 101980 customers remaining
# 1290000 customers processed
# 81980 customers remaining
# 1300000 customers processed
# 71980 customers remaining
# 1310000 customers processed
# 61980 customers remaining
# 1320000 customers processed
# 51980 customers remaining
# 1330000 customers processed
# 41980 customers remaining
# 1340000 customers processed
# 31980 customers remaining
# 1350000 customers processed
# 21980 customers remaining
# 1360000 customers processed
# 11980 customers remaining
# 1370000 customers processed
# 1980 customers remaining

# %%
final_recommendations = final_recommendations.tocsr()

# %%
still_to_recommend = np.where(np.diff(final_recommendations.indptr) == 0)[0]

# %%
final_recommendations = final_recommendations.tolil()

for i, cust in enumerate(still_to_recommend):
    
    cust_id = all_idx_to_customer[cust]
    
    cypher_recs = neo_recs.get_cypher_recs_for_user(cust_id)
    recs = [all_product_to_idx[x] for x in cypher_recs]
    
    final_recommendations[cust ,recs] = 1
    
    if i % 1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000

# %%
final_recommendations = final_recommendations.tocsr()

# %%
sparse.save_npz('final_recommendations.npz', final_recommendations)

# %%
# Still some people - maybe no purchases in the original dataset
np.where(np.diff(final_recommendations.indptr) == 0)[0].shape
# Out:
# (9712,)

# %%
with open('submission.txt', 'w') as f:
    f.write('customer_id,prediction\n')

    for i,row in enumerate(final_recommendations):
        cust_id = all_idx_to_customer[i]
        rec_string = f'{cust_id},{" ".join([all_idx_to_product[rec] for rec in final_recommendations[i].indices])}\n'
        f.write(rec_string)

# %%
# !wc -l submission.csv
# Out:
#  1371981 submission.csv
